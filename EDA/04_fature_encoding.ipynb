# %% [markdown]
# ### 1. Import Dependencies

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# | Variable Type | Preferred Encoding | Why? |
# |--------------|-------------------|------|
# | Nominal | One-Hot Encoding | No inherent order → avoids implying false ordinal relationships |
# | Ordinal | Label Encoding | Preserves order → small integers represent increasing levels |

# %% [markdown]
# ### 2. Data Loading

# %%
df = pd.read_csv('data/processed/ChurnModelling_Binning_Applied.csv')
df.head(10)
# Out:
#    CreditScore Geography  Gender    Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female  42.00       2       0.00              1
# 1          608     Spain  Female  41.00       1   83807.86              1
# 2          502    France  Female  42.00       8  159660.80              3
# 3          699    France  Female  38.91       1       0.00              2
# 4          850     Spain  Female  43.00       2  125510.82              1
# 5          645     Spain    Male  44.00       8  113755.78              2
# 6          822    France    Male  50.00       7       0.00              2
# 7          376   Germany  Female  29.00       4  115046.74              4
# 8          501    France    Male  44.00       4  142051.07              2
# 9          684    France    Male  27.00       2  134603.88              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited CreditScoreBins
# 0          1               1        101348.88       1            Fair
# 1          0               1        112542.58       0            Fair
# 2          1               0        113931.57       1            Poor
# 3          0               0         93826.63       0            Good
# 4          1               1         79084.10       0       Excellent
# 5          1               0        149756.71       1            Fair
# 6          1               1         10062.80       0       Excellent
# 7          1               0        119346.88       1            Poor
# 8          0               1         74940.50       0            Poor
# 9          1               1         71725.73       0            Good

# %% [markdown]
# ### 3. Encode Norminal Varibles

# %%
norminal_variables=['Geography','Gender']
geography_dummies = pd.get_dummies(df['Geography'],prefix='Geography')
gender_dummies = pd.get_dummies(df['Gender'],prefix='Gender')

df_encoded = pd.concat([df,geography_dummies],axis=1)
del df_encoded['Geography']

df_encoded = pd.concat([df_encoded,gender_dummies],axis=1)
del df_encoded['Gender']

df_encoded
# Out:
#       CreditScore    Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619  42.00       2       0.00              1          1
# 1             608  41.00       1   83807.86              1          0
# 2             502  42.00       8  159660.80              3          1
# 3             699  38.91       1       0.00              2          0
# 4             850  43.00       2  125510.82              1          1
# ...           ...    ...     ...        ...            ...        ...
# 9995          771  39.00       5       0.00              2          1
# 9996          516  35.00      10   57369.61              1          1
# 9997          709  36.00       7       0.00              1          0
# 9998          772  42.00       3   75075.31              2          1
# 9999          792  28.00       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited CreditScoreBins  \
# 0                  1        101348.88       1            Fair
# 1                  1        112542.58       0            Fair
# 2                  0        113931.57       1            Poor
# 3                  0         93826.63       0            Good
# 4                  1         79084.10       0       Excellent
# ...              ...              ...     ...             ...
# 9995               0         96270.64       0       Very Good
# 9996               1        101699.77       0            Poor
# 9997               1         42085.58       1            Good
# 9998               0         92888.52       1       Very Good
# 9999               0         38190.78       0       Very Good
#
#       Geography_France  Geography_Germany  Geography_Spain  Gender_Female  \
# 0                 True              False            False           True
# 1                False              False             True           True
# 2                 True              False            False           True
# 3                 True              False            False           True
# 4                False              False             True           True
# ...                ...                ...              ...            ...
# 9995              True              False            False          False
# 9996              True              False            False          False
# 9997              True              False            False           True
# 9998             False               True            False          False
# 9999              True              False            False           True
#
#       Gender_Male
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 9995         True
# 9996         True
# 9997        False
# 9998         True
# 9999        False
#
# [10000 rows x 15 columns]
